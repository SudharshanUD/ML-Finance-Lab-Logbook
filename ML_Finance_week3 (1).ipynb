# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
df = pd.read_csv('telecom_churn.csv')

# Select the two required features
x = df['Total day calls']
y = df['Total night calls']

# Color based on churn (True/False)
churn = df['Churn']

plt.figure(figsize=(8,5))

plt.scatter(x[churn == False], y[churn == False], label='Churn = False')
plt.scatter(x[churn == True],  y[churn == True],  label='Churn = True')

plt.xlabel("Total day calls")
plt.ylabel("Total night calls")
plt.title("Bicolour Feature Diagram: Total day calls vs Total night calls")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
